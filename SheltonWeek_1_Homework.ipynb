# %% [markdown]
# <a href="https://colab.research.google.com/github/ashelt-lja/week4homework/blob/main/SheltonWeek_1_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Homework
#
# (Be sure to save this to Drive before starting)
#
# For this week we are going to practice requesting information from an API and manipulating it as JSON and as a Dataframe.
#
# We are going to keep working with Collection Builder. Head over to the [Collection Builder Example Projects](https://collectionbuilder.github.io/cb-examples/browse.html) listing and find a site that interests you. Spend some time browsing the website to get acquainted with its contents before proceeding with the questions.

# %%
#The Libraries we will need
import requests
import json
import pandas as pd
from random import randrange

# %%
# @markdown **H1** Find the URL of for the  _metadata.json_ of your selected site and paste it in here.
json_cb_url = "https://madelineecollins.github.io/2p90project/assets/data/metadata.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
objects_cb_data = total_cb_data['objects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# **H2** Run the 'show random cell' a few times to get a sense of what kind of data is in your chosen site.

# %%
#Run this a few times to see random entries in the JSON data that you retrieved.
random_entry = randrange(len(objects_cb_data))
print(json.dumps(objects_cb_data[random_entry],indent=2))
# Out:
# {
#   "title": "The Excavation of the Canadian Channel for a Forebay",
#   "date": "1906",
#   "description": "A photograph from the Adams article depicting the excavation and construction of a forebay in the Canadian Channel. A forebay is an artifical reservoir which holds water and diverts it to the power stations. Brock University Archives and Special Collections, Niagara Falls/Niagara Power collection RG 86.",
#   "subject": "hydroelectricity; excavation; diversion; industrialization",
#   "location": "Niagara Falls NY",
#   "latitude": "43.1039322",
#   "longitude": "-79.03896251",
#   "format": "image/jpg",
#   "reference_url": "https://github.com/madelineecollins/2p90project/item.html?id=item5"
# }

# %% [markdown]
# ## Different Fields!
#
# You can create any number of datafields and correpsonding values for those fields with a Collection Builder site. So the results from the output from the cell above will probably have wildly different results from [my site](https://elibtronic.github.io/AIL_Database/data.html) that we worked on in the Workalong notebook.
#
#
# You can see all of these options from grabbing the _facets.json_ URL from a collection builder homepage. Find that URL for your selected site for **H3**

# %%
# @markdown **H3** Find the URL of the facets.json for your selected site and paste it in here.
json_cb_facets_url = "https://madelineecollins.github.io/2p90project/assets/data/facets.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_facets_url)
#all of the data from the sites
total_facet_data = response_cb.json()
#just the 'objects' indexed in the site
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# Run the cell below to see what the facets used for this site:

# %%
print(json.dumps(total_facet_data,indent=2))
# Out:
# {
#   "facets": [
#     {
#       "field": "subject",
#       "terms": {
#         "`": 1,
#         "abolition": 1,
#         "advertising": 1,
#         "article": 2,
#         "bridal veil": 2,
#         "bridge": 5,
#         "business": 1,
#         "caricature": 1,
#         "cave": 1,
#         "clifton hill": 1,
#         "critique": 2,
#         "development": 2,
#         "diversion": 4,
#         "excavation": 1,
#         "goat island": 1,
#         "horseshoe tower": 1,
#         "hotel": 1,
#         "hydroelectricity": 8,
#         "industrialization": 8,
#         "magazine": 1,
#         "map": 1,
#         "mills": 1,
#         "photogravure": 2,
#         "plants": 2,
#         "power company": 1,
#         "prospect point": 1,
#         "rainbow": 1,
#         "river": 4,
#         "streetcar": 1,
#         "terrapin tower": 1,
#         "text": 2,
#         "tourism": 9,
#         "unspoiled landscape": 6,
#         "water diversion": 1,
#         "water rights": 3,
#         "winter": 1
#       }
#     },
#     {
#       "field": "creator",
#       "terms": {}
#     },
#     {
#       "field": "format",
#       "terms": {
#         "application/pdf": 2,
#         "image/jpg": 18
#       }
#     }
#   ]
# }

# %% [markdown]
# **H3** Try to read the JSON that is displayed to the screen. What possible facets are there in the the data. Fill them in the markdown list in the cell below. Add as many entries as you need to describe the site

# %% [markdown]
# Facets in my site are:
#
#
# *   Subject
# *   Creator
# *   Format

# %% [markdown]
# **H4** Which facet shows up the most for your selected site? Put your answer in the cell below

# %% [markdown]
# This facet that shows up the most is image/jpg it is used 18 times on my selected site.

# %% [markdown]
# **H5** Turn the site _metadata.json_ data into a dataframe by completing the cell below. Part of it is written for you. You just need to modify line 4.

# %%
#H5

cb_data = pd.read_json(json_cb_url)
cb_normalized = pd.json_normalize(cb_data['objects'])
cb_normalized
# Out:
#                                                 title        date  \
# 0   Description of the Natural Beauty of the Falls...        1852
# 1   Continued: Description of the Natural Beauty o...        1852
# 2     Aerial View of Both Falls, Facing Victoria Park        1921
# 3   "Niagara Falls Already Ruined!" by Alton D. Adams        1906
# 4   The Excavation of the Canadian Channel for a F...        1906
# 5          Map of Power Developments at Niagara Falls        1904
# 6                                  The Cataract House         NaN
# 7                A View of the Bank of American Mills  1897-06-05
# 8                   Caricature of the Power Companies        1909
# 9                           A Crowd at Prospect Point        1901
# 10  A View of the Falls From Under a Suspension Br...         NaN
# 11                            Upper Steel Arch Bridge        1898
# 12                                 Goat Island Bridge        1898
# 13                        Cave of the Winds Newsprint         NaN
# 14         "The Passing of Niagara", by Mary B. Hartt        1901
# 15                    The Pre-Industrial Bridal Veil         1901
# 16                       Tourists at the Frozen Falls         NaN
# 17                      Man on Niagara Clifton Bridge         NaN
# 18                 Terrapin Tower and Horseshoe Falls         NaN
# 19                 Another View of the Power Stations        1906
#
#                                           description  \
# 0   Part 1 from an account about the natural beaut...
# 1   Part 2 from the account of the natural beauty ...
# 2   This is an image from a tourist guide called "...
# 3   This is a magazine article hotly criticizing t...
# 4   A photograph from the Adams article depicting ...
# 5   A historical map detailing the boundaries, hyd...
# 6   The Cataract House was a hotel constructed in ...
# 7   A photograph from a magazin article that shows...
# 8   A cartoon of a "commerical exploiter" whose "c...
# 9   A stereo card showing a crowd of interested to...
# 10  A stereo card showing two viewers admiring the...
# 11  A photogravure from the tourist guide "Photo-g...
# 12  A photogravure from the tourist guide "Photo-g...
# 13  A promotional print detailing the bridges, dre...
# 14  Another excellent example of the nineteenth ce...
# 15  A photograph by George E. Curtis showing what ...
# 16  A stereo card showing crowds of tourists gathe...
# 17  A man poses looking over the edge of the Niaga...
# 18  A photograph by George E. Curtis of the top of...
# 19  Another view of the power stations along the l...
#
#                                               subject          location  \
# 0                           text; unspoiled landscape  Niagara Falls NY
# 1                           text; unspoiled landscape  Niagara Falls NY
# 2   photogravure; development; tourism; clifton hill   Niagara Falls ON
# 3   water rights; diversion; magazine; article; in...  Niagara Falls NY
# 4   hydroelectricity; excavation; diversion; indus...  Niagara Falls NY
# 5   hydroelectricity; plants; map; development; bu...  Niagara Falls ON
# 6        tourism; hotel; industrialization; abolition  Niagara Falls NY
# 7         hydroelectricity; plants; water diversion;`  Niagara Falls ON
# 8   caricature; power company; water rights; hydro...  Niagara Falls NY
# 9                             tourism; prospect point  Niagara Falls NY
# 10          tourism; bridge; river; industrialization  Niagara Falls ON
# 11  bridge; river; streetcar; industrialization; p...  Niagara Falls ON
# 12                bridge; river; goat island; tourism  Niagara Falls NY
# 13                tourism; cave; rainbow; advertising  Niagara Falls NY
# 14  hydroelectricity; unspoiled landscape; critiqu...  Niagara Falls NY
# 15  hydroelectricity; mills; water rights; bridal ...  Niagara Falls NY
# 16                                    tourism; winter  Niagara Falls NY
# 17          tourism; bridge; river; industrialization  Niagara Falls NY
# 18  tourism; terrapin tower; industrialization; br...  Niagara Falls ON
# 19  hydroelectricity; unspoiled landscape; critiqu...  Niagara Falls NY
#
#        latitude     longitude           format  \
# 0    43.1039322  -79.03896251        image/jpg
# 1    43.1039322  -79.03896251        image/jpg
# 2   43.04983302  -79.10040274        image/jpg
# 3    43.1039322  -79.03896251  application/pdf
# 4    43.1039322  -79.03896251        image/jpg
# 5   43.04983302  -79.10040274        image/jpg
# 6    43.1039322  -79.03896251        image/jpg
# 7   43.04983302  -79.10040274        image/jpg
# 8    43.1039322  -79.03896251        image/jpg
# 9    43.1039322  -79.03896251        image/jpg
# 10  43.04983302  -79.10040274        image/jpg
# 11  43.04983302  -79.10040274        image/jpg
# 12   43.1039322  -79.03896251        image/jpg
# 13   43.1039322  -79.03896251        image/jpg
# 14   43.1039322  -79.03896251  application/pdf
# 15   43.1039322  -79.03896251        image/jpg
# 16   43.1039322  -79.03896251        image/jpg
# 17   43.1039322  -79.03896251        image/jpg
# 18  43.04983302  -79.10040274        image/jpg
# 19   43.1039322  -79.03896251        image/jpg
#
#                                         reference_url
# 0   https://github.com/madelineecollins/2p90projec...
# 1   https://github.com/madelineecollins/2p90projec...
# 2   https://github.com/madelineecollins/2p90projec...
# 3   https://github.com/madelineecollins/2p90projec...
# 4   https://github.com/madelineecollins/2p90projec...
# 5   https://github.com/madelineecollins/2p90projec...
# 6   https://github.com/madelineecollins/2p90projec...
# 7   https://github.com/madelineecollins/2p90projec...
# 8   https://github.com/madelineecollins/2p90projec...
# 9   https://github.com/madelineecollins/2p90projec...
# 10  https://github.com/madelineecollins/2p90projec...
# 11  https://github.com/madelineecollins/2p90projec...
# 12  https://github.com/madelineecollins/2p90projec...
# 13  https://github.com/madelineecollins/2p90projec...
# 14  https://github.com/madelineecollins/2p90projec...
# 15  https://github.com/madelineecollins/2p90projec...
# 16  https://github.com/madelineecollins/2p90projec...
# 17  https://github.com/madelineecollins/2p90projec...
# 18  https://github.com/madelineecollins/2p90projec...
# 19  https://github.com/madelineecollins/2p90projec...

# %%
#Run this a few times to see random entries in your dataframe
cb_normalized.sample(10)
# Out:
#                                                 title  date  \
# 2     Aerial View of Both Falls, Facing Victoria Park  1921
# 12                                 Goat Island Bridge  1898
# 10  A View of the Falls From Under a Suspension Br...   NaN
# 9                           A Crowd at Prospect Point  1901
# 0   Description of the Natural Beauty of the Falls...  1852
# 4   The Excavation of the Canadian Channel for a F...  1906
# 15                    The Pre-Industrial Bridal Veil   1901
# 16                       Tourists at the Frozen Falls   NaN
# 17                      Man on Niagara Clifton Bridge   NaN
# 13                        Cave of the Winds Newsprint   NaN
#
#                                           description  \
# 2   This is an image from a tourist guide called "...
# 12  A photogravure from the tourist guide "Photo-g...
# 10  A stereo card showing two viewers admiring the...
# 9   A stereo card showing a crowd of interested to...
# 0   Part 1 from an account about the natural beaut...
# 4   A photograph from the Adams article depicting ...
# 15  A photograph by George E. Curtis showing what ...
# 16  A stereo card showing crowds of tourists gathe...
# 17  A man poses looking over the edge of the Niaga...
# 13  A promotional print detailing the bridges, dre...
#
#                                               subject          location  \
# 2   photogravure; development; tourism; clifton hill   Niagara Falls ON
# 12                bridge; river; goat island; tourism  Niagara Falls NY
# 10          tourism; bridge; river; industrialization  Niagara Falls ON
# 9                             tourism; prospect point  Niagara Falls NY
# 0                           text; unspoiled landscape  Niagara Falls NY
# 4   hydroelectricity; excavation; diversion; indus...  Niagara Falls NY
# 15  hydroelectricity; mills; water rights; bridal ...  Niagara Falls NY
# 16                                    tourism; winter  Niagara Falls NY
# 17          tourism; bridge; river; industrialization  Niagara Falls NY
# 13                tourism; cave; rainbow; advertising  Niagara Falls NY
#
#        latitude     longitude     format  \
# 2   43.04983302  -79.10040274  image/jpg
# 12   43.1039322  -79.03896251  image/jpg
# 10  43.04983302  -79.10040274  image/jpg
# 9    43.1039322  -79.03896251  image/jpg
# 0    43.1039322  -79.03896251  image/jpg
# 4    43.1039322  -79.03896251  image/jpg
# 15   43.1039322  -79.03896251  image/jpg
# 16   43.1039322  -79.03896251  image/jpg
# 17   43.1039322  -79.03896251  image/jpg
# 13   43.1039322  -79.03896251  image/jpg
#
#                                         reference_url
# 2   https://github.com/madelineecollins/2p90projec...
# 12  https://github.com/madelineecollins/2p90projec...
# 10  https://github.com/madelineecollins/2p90projec...
# 9   https://github.com/madelineecollins/2p90projec...
# 0   https://github.com/madelineecollins/2p90projec...
# 4   https://github.com/madelineecollins/2p90projec...
# 15  https://github.com/madelineecollins/2p90projec...
# 16  https://github.com/madelineecollins/2p90projec...
# 17  https://github.com/madelineecollins/2p90projec...
# 13  https://github.com/madelineecollins/2p90projec...

# %% [markdown]
# **H6** This is for bonus!
# Try to write a pandas statement that will display your answer from **H4**. There are plenty of ways to do this, so feel free to use your imagination. What I have started for you here might not work, so feel free to change it as needed.

# %%
cb_normalized[cb_normalized["format"] == "image/jpg"].count()
# Out:
# title            18
# date             12
# description      18
# subject          18
# location         18
# latitude         18
# longitude        18
# format           18
# reference_url    18
# dtype: int64

# %% [markdown]
# ## All Done!
#
# Congrats you are finished with this week's work. First save as PDF so that you can upload to the Course site then click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work.
